# %%
import os
from pathlib import Path

from ....services.crewai_service import crewai_service
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 4
#       1 import os
#       2 from pathlib import Path
# ----> 4 from ....services.crewai_service import crewai_service
#
# ImportError: attempted relative import with no known parent package

# %%
user_media_dir = "/home/aldou/codes/ai/fast-api/media/altest"
file_name = "29c4c757-3428-476e-b9c0-cf475e398ba6.jpeg"
file_path = user_media_dir / file_name

# %%
crewai_service.start_poem_generation(
    poem_source_id=2,
    image_path=str(file_path),
    user_id=34,
    enhance="",
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 crewai_service.start_poem_generation(
#       2     poem_source_id=2,
#       3     image_path=str(file_path),
#       4     user_id=34,
#       5     enhance="",
#       6     db_session_maker=local_session
#       7 )
#
# NameError: name 'crewai_service' is not defined
